# %%
import h5py
import numpy as np
from matplotlib import pyplot as plt

# %%
f = h5py.File('storag.h5','r')

# %%
f['map'].keys()
# Out:
# <KeysViewHDF5 ['stage_t=43.83081306154468', 'stage_t=87.66162612325483']>

# %%
print(f['map']['stage_t=87.66162612325483']['T'].compression)
# Out:
# None

# %%
z= np.array(f['map']['stage_t=87.66162612325483']['T']).T

# %%
plt.contourf(z)
