# %%
import  matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import shutil
import matplotlib.animation as animation

# %%
def contur_plot(df):
    fig,ax = plt.subplots(1,3,figsize=(9,3))
    NX= len(df.x.unique())
    NY= len(df.y.unique())

    x = df.x.unique()
    y = df.y.unique()

    X, Y = np.meshgrid(x, y)  
    z = df['psi'].to_numpy().reshape((NY, NX))
    cs = ax[0].contourf(X, Y, z,cmap=plt.cm.rainbow)
    #z = df['phi'].to_numpy().reshape((NY, NX))
   # cs = ax[1].contourf(X, Y, z,cmap=plt.cm.rainbow)
    z = df['T'].to_numpy().reshape((NY, NX))
    cs = ax[1].contourf(X, Y, z,cmap=plt.cm.rainbow)
    z = df['C'].to_numpy().reshape((NY, NX))
    cs = ax[2].contourf(X, Y, z,cmap=plt.cm.rainbow)
    plt.show()
def contur_plot2(df):
    fig,ax = plt.subplots(figsize=(6,3))
    NX= len(df.x.unique())
    NY= len(df.y.unique())

    x = df.x.unique()
    y = df.y.unique()

    X, Y = np.meshgrid(x, y)  

    z = df['C'].to_numpy().reshape((NY, NX))
    cs = ax.contour(X, Y, z,colors='k')
    plt.savefig('1.png',dpi=600)
    plt.show()

# %%
from IPython.display import HTML

# %%
import os
from pathlib import Path

# %%
paths = sorted(Path('res').iterdir(), key=os.path.getmtime)
paths[-1]
# Out:
# PosixPath('res/stage_t=2400.277488717388.dat')

# %%
sor*rel/bm/l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sor*rel/bm/l
#
# NameError: name 'sor' is not defined

# %%
0.16*32
# Out:
# 5.12

# %%
NX= len(df.x.unique())
NY= len(df.y.unique())
z = df['C'].to_numpy().reshape((NY, NX))

x= np.linspace(0,20,32)
l=32
sor=8.8
rel=0.019
bm=0.16
H=20

gama=-(sor*rel/bm/l-1/l)
plt.plot(H*gama*np.exp(-x*gama)/(1-np.exp(-H*gama)),ls='--')
#plt.plot(20/l*np.exp(-x/l)/(1-np.exp(-20/l)))
plt.plot((z[:,NX//2]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 NX= len(df.x.unique())
#       2 NY= len(df.y.unique())
#       3 z = df['C'].to_numpy().reshape((NY, NX))
#
# NameError: name 'df' is not defined

# %%
gama
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 gama
#
# NameError: name 'gama' is not defined

# %%
0.16*32
# Out:
# 5.12

# %%
paths = sorted(Path('res').iterdir(), key=os.path.getmtime)
for x in paths[-5::]:
    df = pd.read_csv(x)
    contur_plot(df)
# Out:
# <img src="data:image/png;base64,..." width="900.1666666666667">
# <img src="data:image/png;base64,..." width="900.1666666666667">
# <img src="data:image/png;base64,..." width="900.1666666666667">
# <img src="data:image/png;base64,..." width="900.1666666666667">
# <img src="data:image/png;base64,..." width="900.1666666666667">

# %%
df =pd.read_csv('foo.csv')
df.plot('t','psi_m')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <AxesSubplot: xlabel='t'>

# %%
df =pd.read_csv('no_v/foo.csv')
df.plot('t','psi_m')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <AxesSubplot: xlabel='t'>

# %%
df =pd.read_csv('reg2//foo.csv')
df.plot('t','psi_m')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <AxesSubplot: xlabel='t'>

# %%
df =pd.read_csv('foo.csv')

# %%
5.12/32
# Out:
# 0.16

# %%
# %matplotlib notebook

# %%
fig,ax = plt.subplots(1,3,figsize=(9,3))
paths = sorted(Path('res').iterdir(), key=os.path.getmtime)
paths=paths[:]
# Method to change the contour data points
def animate(i):
    stage= paths[i]
    df = pd.read_csv(stage)
    NX= len(df.x.unique())
    NY= len(df.y.unique())

    x = df.x.unique()
    y = df.y.unique()
    ax[0].clear()
    ax[1].clear()
    ax[2].clear()
    
    X, Y = np.meshgrid(x, y)  
    z = df['psi'].to_numpy().reshape((NY, NX))
    cs = ax[0].contourf(X, Y, z,cmap=plt.cm.rainbow)
    #z = df['phi'].to_numpy().reshape((NY, NX))
   # cs = ax[1].contourf(X, Y, z,cmap=plt.cm.rainbow)
    ax[1].set_title(stage)
    z = df['T'].to_numpy().reshape((NY, NX))
    cs = ax[1].contourf(X, Y, z,cmap=plt.cm.rainbow,levels=100)
    z = df['C'].to_numpy().reshape((NY, NX))
    cs = ax[2].contourf(X, Y, z,cmap=plt.cm.rainbow,levels=100)
# Call animate method
ani = animation.FuncAnimation(fig, animate, len(paths), interval=30, blit=False)

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fig,ax = plt.subplots(1,3,figsize=(9,3))
#       2 paths = sorted(Path('res').iterdir(), key=os.path.getmtime)
#       3 paths=paths[:]
#
# NameError: name 'plt' is not defined

# %%
ani.save('1.avi')

# %%
5.12 /32
# Out:
# 0.16

# %%
df.plot('y','C')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df.plot('y','C')
#
# File ~/.local/lib/python3.9/site-packages/pandas/plotting/_core.py:965, in PlotAccessor.__call__(self, *args, **kwargs)
#     963 if is_integer(x) and not data.columns.holds_integer():
#     964     x = data_cols[x]
# --> 965 elif not isinstance(data[x], ABCSeries):
#     966     raise ValueError("x must be a label or position")
#     967 data = data.set_index(x)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'y'

# %%
df2.plot('t','nu')
