# %%
import  matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import matplotlib.animation as animation

# %%
from IPython.display import HTML

# %%
import os
from pathlib import Path

# %%
20*1.6
# Out:
# 32.0

# %%
paths = sorted(Path('res').iterdir(), key=os.path.getmtime)
paths[-1]
# Out:
# PosixPath('res/stage_t=951.2485136653908.dat')

# %%
NX= len(df.x.unique())
NY= len(df.y.unique())
z = df['C'].to_numpy().reshape((NY, NX))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 NX= len(df.x.unique())
#       2 NY= len(df.y.unique())
#       3 z = df['C'].to_numpy().reshape((NY, NX))
#
# NameError: name 'df' is not defined

# %%
x= np.linspace(0,20,30)
l=1.6*20
plt.plot(20/l*np.exp(-x/l)/(1-np.exp(-20/l)))
#plt.plot(20/l*np.exp(-x/l)/(1-np.exp(-20/l)))
plt.plot((z[:,NX//2]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 plt.plot(20/l*np.exp(-x/l)/(1-np.exp(-20/l)))
#       4 #plt.plot(20/l*np.exp(-x/l)/(1-np.exp(-20/l)))
# ----> 5 plt.plot((z[:,NX//2]))
#
# NameError: name 'z' is not defined

# %%
0.16*1.6
# Out:
# 0.256

# %%
plt.plot(np.diff(z[:,NX//2]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.plot(np.diff(z[:,NX//2]))
#
# NameError: name 'z' is not defined

# %%
paths = sorted(Path('res').iterdir(), key=os.path.getmtime)
for x in paths[-5::]:
    df = pd.read_csv(x)
    contur_plot(df)

# %%
df =pd.read_csv('foo.csv')
df.plot('t','psi_m')
# Out:
# <AxesSubplot: xlabel='t'>

# %%
df =pd.read_csv('foo.csv')

# %%
df
# Out:
#                 t         psi_m         psi_l        nu
# 0        1.585414  2.820804e-08 -9.125342e-09 -1.016043
# 1        3.170828  2.588178e-08 -8.947585e-09 -1.016043
# 2        4.756243  2.437224e-08 -8.648025e-09 -1.016043
# 3        6.341657  2.327260e-08 -8.277831e-09 -1.016043
# 4        7.927071  2.241922e-08 -7.881208e-09 -1.016043
# ...           ...           ...           ...       ...
# 1500  2379.706698  7.223527e-09 -3.450998e-10 -1.016043
# 1501  2381.292113  1.142604e-08  2.938287e-10 -1.016043
# 1502  2382.877527  1.582812e-08  9.356438e-10 -1.016043
# 1503  2384.462941  2.030993e-08  1.580300e-09 -1.016043
# 1504  2386.048355           NaN           NaN       NaN
#
# [1505 rows x 4 columns]

# %%
# %matplotlib notebook

# %%
fig,ax = plt.subplots(1,3,figsize=(9,3))
paths = sorted(Path('res').iterdir(), key=os.path.getmtime)
paths=paths[-300:]
# Method to change the contour data points
def animate(i):
    stage= paths[i]
    df = pd.read_csv(stage)
    NX= len(df.x.unique())
    NY= len(df.y.unique())

    x = df.x.unique()
    y = df.y.unique()
    ax[0].clear()
    ax[1].clear()
    ax[2].clear()
    
    X, Y = np.meshgrid(x, y)  
    z = df['psi'].to_numpy().reshape((NY, NX))
    cs = ax[0].contourf(X, Y, z,cmap=plt.cm.rainbow)
    #z = df['phi'].to_numpy().reshape((NY, NX))
   # cs = ax[1].contourf(X, Y, z,cmap=plt.cm.rainbow)
    ax[1].set_title(stage)
    z = df['T'].to_numpy().reshape((NY, NX))
    cs = ax[1].contourf(X, Y, z,cmap=plt.cm.rainbow)
    z = df['C'].to_numpy().reshape((NY, NX))
    cs = ax[2].contourf(X, Y, z,cmap=plt.cm.rainbow)
# Call animate method
ani = animation.FuncAnimation(fig, animate, len(paths), interval=5, blit=False)

# Display the plot
plt.show()

# %%
ani
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ani
#
# NameError: name 'ani' is not defined

# %%
def contur_plot(df):
    fig,ax = plt.subplots(1,3,figsize=(9,3))
    NX= len(df.x.unique())
    NY= len(df.y.unique())

    x = df.x.unique()
    y = df.y.unique()

    X, Y = np.meshgrid(x, y)  
    z = df['psi'].to_numpy().reshape((NY, NX))
    cs = ax[0].contourf(X, Y, z,cmap=plt.cm.rainbow)
    #z = df['phi'].to_numpy().reshape((NY, NX))
   # cs = ax[1].contourf(X, Y, z,cmap=plt.cm.rainbow)
    z = df['T'].to_numpy().reshape((NY, NX))
    cs = ax[1].contourf(X, Y, z,cmap=plt.cm.rainbow)
    z = df['C'].to_numpy().reshape((NY, NX))
    cs = ax[2].contourf(X, Y, z,cmap=plt.cm.rainbow)
    plt.show()

# %%
def contur_plot2(df):
    fig,ax = plt.subplots(figsize=(6,3))
    NX= len(df.x.unique())
    NY= len(df.y.unique())

    x = df.x.unique()
    y = df.y.unique()

    X, Y = np.meshgrid(x, y)  

    z = df['C'].to_numpy().reshape((NY, NX))
    cs = ax.contour(X, Y, z,colors='k')
    plt.savefig('1.png',dpi=600)
    plt.show()

# %%
df.plot('y','C')
# Out:
# <AxesSubplot: xlabel='y'>

# %%
df2.plot('t','nu')
# Out:
# <AxesSubplot: xlabel='t'>
